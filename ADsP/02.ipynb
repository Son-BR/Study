# %% [markdown]
# # Ⅱ. 데이터 분석 기획
#
# ---
#
# ## 1. 데이터 분석 기획의 이해
#
# ========================================================================================================================
#
# ### 1.1 분석 기획 방향성 도출
#
# #### 1, 데이터의 유형
#
#
#
# ### 1.2 분석 방법론
# ### 1.3 분석 과제 발굴
# ### 1.4 분석 프로젝트 관리 방안

# %% [markdown]
# # Ⅰ. 데이터의 이해
#
# ---
#
# ## 1. 데이터의 이해
#
# ========================================================================================================================
#
# ### 1.1 데이터와 정보
#
# #### 1, 데이터의 유형
#
# #### 2, 지식경영의 핵심 이슈
#
# #### 3, DIKW 피라미드
#
# ========================================================================================================================
#
# ### 1.2 데이터베이스 정의와 특징
#
# #### 1. 데이터베이스 정의
#
# #### 2. 데이터베이스 특징
#
# ========================================================================================================================
#
# ---
#
# ## 2. 데이터의 가치와 미래
#
# ========================================================================================================================
#
# ### 2.1 빅데이터의 이해
#
# #### 1. 빅데이터의 정의
#
# #### 2. 출현 배경과 변화
#
# #### 3. 빅데이터에 거는 기대의 비유적 표현
#
# #### 4. 빅데이터가 만들어내는 본질적인 변화
#
# ========================================================================================================================
#
# ### 2.2 빅데이터의 가치와 영향
#
# #### 1. 빅데이터의 가치 산정이 어려운 이요
#
# #### 2. 빅데이터의 영향
